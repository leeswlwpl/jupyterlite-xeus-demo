# %% [markdown]
# ## BI Project - Profitability Analysis

# %% [markdown]
# In this project, you will create some metrics on the performance of your company and identify areas that can improve. You can download the E-Commerce dataset from Kaggle <a href="https://www.kaggle.com/datasets/benroshan/ecommerce-data" target="_blank"> here </a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Task 1 - Load and transform data
#
# First we will import the list of orders information.<br>
#
# Step 1: Import the csv file named "List of Orders" by selecting “Text/CSV” in Get Data <br>
# Step 2: Select Transform Data, change the data type of "Order Date" to "Date"<br>
# Step 3: Select Reduce Rows > Remove Rows > Remove Blank Rows <br>
# Step 4: Select Close & Apply <br>

# %% [markdown]
# After importing list of orders, we will also import the order details.<br>
#
# Step 1: Import the csv file named "Order Details" by selecting “Text/CSV” in Get Data<br>
# Step 2: Select Load<br>

# %% [markdown]
# ### Task 2 - Format data
#
# We are going to update the "Amount" and "Profit" fields to currency.<br>
#
# Step 1: Go to Table View at the left bar<br>
# Step 2: Select the “Order Details” file<br>
# Step 3: Select the “Profit” column<br>
# Step 4: Select the Format dropdown and select "Currency"<br>

# %% [markdown]
# ### Task 3 - Join data
#
# Since we have two tables of data, we would like to join the two tables by establishing connection.<br>
#
# Step 1: Go to Model View at the left bar<br>
# Step 2: Drag the "Order ID" field from "Order Details" table to the "Order ID" fields from "List of Orders" table<br>
# Step 3: Select "Many to one" for Cardinality between "Order Details" and "List of Orders" because each "Order ID" is unique in "List of Orders" table with multiple "Order ID" in "Order Details" table<br>

# %% [markdown]
# ### Task 4 - Define KPIs
#
# We would like to create KPIs to measure profit, order quantity and number of orders. In this case we will create a multiple card.<br>
#
# Step 1: Select Multi-row card from the Visualizations<br>
# Step 2: Select “Profit”, “Quantity” and “Order ID” for the Fields<br>
# Step 3: Select the dropdown on “Order ID” and change it to Count Distinct<br>
# Step 4: Select Rename for this visual under the “Order ID” dropdown and change the title to “# of Orders”<br>
# Step 5: Go to Format under Visualizations > Cards > Select Top and Bottom for Border position <br>
# Step 6: Resize to take up the top header of the page

# %% [markdown]
# ### Task 5 - Identify Profit Trend
#
# We would like to observe the trends of profit over time, broken down by category. In this case we will create a link and stacked column chart.<br>
#
# Step 1: Select the “Line and stacked column chart” from the Visualizations<br>
# Step 2: Move "Order Date" into the X-axis and remove "Day" and "Quarter"<br>
# Step 3: Move "Category" into Column legend<br>
# Step 4: Move "Profit" into Line y-axis, select "Sum of Profit"<br>
# Step 5: Move "Order ID" into Column y-axis, select Count of Order ID<br>
# Step 6: Select “Expand all down one level in the hierarchy” at the top right of the chart<br>
# Step 7: Go to Format under Visualizations > X-axis > turn off Concatenate labels > update the Title text<br>
# Step 8: Resize and place below the KPI chart

# %% [markdown]
# ### Task 6 - Visualize Profit by Category
#
# We would like to quickly identify the profit by categories and sub-categories so we can take action accordingly. In this case we will create a heatmap.<br>
#
# Step 1: Select the Matrix chart from the Visualizations<br>
# Step 2: Move “Sub-Category” to Rows<br>
# Step 3: Move “Category” to Columns<br>
# Step 4: Move “Profit” to Values, select "Sum of Profit"<br>
# Step 5: Resize so you can see all of the items in the chart<br>
# Step 6: Go to Format under Visualizations > Turn Title on > Name the chart under Text<br>
# Step 7: Go to Cell elements > Backgounrd color > Conditional Formatting<br>
# Step 8: Select "Sum of Profit” under field and change the Minimum color to red<br>
# Step 9: Tick "Add a middle color", change the center to be custom and enter “0”<br>
# Step 10: Resize and place next to the Profit Trend Chart<br>

# %% [markdown]
# ### Task 7 - Analyze Profitability by Customer
#
# We would like to identify which cusotmers are contributing profit and loss to us. In this case we will create a scatter chart.<br>
#
# Step 1: Select the Scatter chart from Visualizations<br>
# Step 2: Move “Customer Name” to Tooltips<br>
# Step 3: Move “Amount” to the X axis<br>
# Step 4: Move “Profit” to the Y axis<br>
# Step 5: Select Format > General > Turn Title on > Name the chart under Text<br>
# Step 6: Select Markers > Color > Conditional Formatting<br>
# Step 7: Select “Sum of Profit” under fields and change the Minimum color to be red<br>
# Step 8: Change the Minimum value to be Custom and “-1”<br>
# Step 9: Change the Maximum value to be Custom and “1”<br>
# Step 10: Resize and place below the Profit Trend Chart<br>

# %% [markdown]
# ### Task 8 - Analyze the Profit by Location
#
# We would like to identify profitability by location. In this case we will create a tree map.<br>
#
# Step 1: Select the “tree map” from Visualizations<br>
# Step 2: Move “Profit” to the tooltips, select "Sum of Profit"<br>
# Step 3: Move “Amount” to the Values, select "Sum of Amount"<br>
# Step 4: Move “State” to the Category<br>
# Step 5: Go to Format > Colors > Advanced controls > Conditional Formatting<br>
# Step 6: Select “Sum of Profit” in fields, change the Minimum color to be red<br>
# Step 7: Tick "Add a middle color", change the center to be custom and enter “0”<br>
# Step 8: Resize and place next to the Scatter Chart<br>

# %% [markdown]
# ### Task 9 - Key influencers
#
# We would like to understand what are the key factors driving the profit. In this case we will create a Key influencers chart<br>
#
# Step 1: Create a new page by clicking the "+" button at the bottom<br>
# Step 2: Select the Key Influencers chart from Visualization<br>
# Step 3: Move "Amount" to Analyze<br>
# Step 4: Move "Category" and "Sub-Category" to the Explain By<br>

# %% [markdown]
# ### Task 10 - Q&A Chart
#
# In Power BI, there is an interesting chart called Q&A Chart, which allows users to ask questions in plain language and receive dynamic visualizations and insights in response.<br>
#
# Step 1: Select the Q&A chart type<br>
# Step 2: Resize and place next ot the Key Influencers chart<br>

# %% [markdown]
# ### Task 11 - Filters and Slicers
#
# The last thing we would like to do is to add some filters and slicers.<br>
#
# We will add a date slicer on the Profit Analysis page.<br>
# Step 1: Select the Slicer chart type <br>
# Step 2: Move "Order Date" into Field <br>
# Step 3: Resize and place it next to the KPI chart<br>
#
# We will also add filters to the report page.<br>
# Step 1: Select "City" and move to the “Filters on this page”<br>
# Step 2: Select "Customer Name" and move to the “Filters on this page”<br>
# Step 3: Select "State" and move to the “Filters on this page”<br>
# Step 4: Select "Category" and move to the “Filters on this page”<br>
# Step 5: Select "Sub-Category" and move to the “Filters on this page”<br>

# %% [markdown]
# ### Task 12 - Start your Analysis
#
# Looking at the data, can you answer below questions?
#
# 1. Is there an inflection point for profitablity? If yes which year?
# 2. Which category and sub-category we should look at because it is loss-making?
# 3. Around what percentage of customers are loss-making?
# 4. Which location are loss-making?
# 5. Which products are the key drivers of our revenue?

# %%
# Type your answer here
