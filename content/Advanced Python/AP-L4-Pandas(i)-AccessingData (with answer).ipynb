# %% [markdown]
# ## 1. Introduction to Pandas

# %% [markdown]
# Pandas is a Python module for working with tabular data (i.e., data in a table with rows and columns). Tabular data has a lot of the same functionality as SQL or Excel, but Pandas enhance the power of Python.
#
# In order to get access to the Pandas module, we’ll need to install the module and then import it into a Python file

# %%
# ANS
import pandas as pd

# %% [markdown]
# In this lesson, you’ll learn the basics of working with a single table in Pandas, such as:
#
# 1. Create a table from scratch <br>
# 2. Loading data from another file <br>
# 3. Selecting certain rows or columns of a table

# %% [markdown]
# ## 2. Pandas's data types

# %% [markdown]
# By far we have learn some standard Python data types:
# 1. String
# 2. Integer
# 3. Float
# 4. Boolean
# 5. List
# 6. Dictionary
# 7. Set
# 8. Tuple
# 9. None Type
# 10. Datetime
# 11. Callable (e.g. a function)
#
# Please refer to Python Explorer if you have already forgotten them.
#
# In Pandas we introduce three new data types:
# 1. DataFrame
# 2. Series
# 3. Index

# %% [markdown]
# ### 2.1 DataFrame
#
# - A DataFrame is an object that stores data as rows and columns.
# - Think of a DataFrame as a spreadsheet or as a SQL table.
# - DataFrames have rows and columns.
# - Each column has a name, which is normally a string, but can also be of other data types.
# - Each row has an index, which can be an integer, a string, a datetime or other data types.

# %% [markdown]
# ### 2.2 Series
# - A series stores a sequence of values, like a list
# - It is accompanied with an index

# %% [markdown]
# ### 2.3 Index
# - Stores a list of value
# - Optimized for fast searching
# - Attached to DataFrames and Series

# %% [markdown]
# ## 3. Create a DataFrame

# %% [markdown]
# ### 3.1 Column data

# %% [markdown]
# - You can pass in a dictionary to `pd.DataFrame()`. Each key is a column name and each value is a list of column values. The columns must all be the same length or you will get an error. Here’s an example:

# %%
# Example of creating a DataFrame

df1 = pd.DataFrame({
    "name": ["John Smith", "Jane Doe", "Joe Schmo"],
    "address": ["123 Main St.", "456 Maple Ave.", "789 Broadway"],
    "age": [34, 28, 51]
})

# %%
df1

# %% [markdown]
# **Exercise**
#
# > Create a DataFrame with the following data:
# ```
# | Product ID | Product Name | Color |
# |------------|--------------|-------|
# | 1          | t-shirt      | blue  |
# | 2          | t-shirt      | green |
# | 3          | skirt        | red   |
# | 4          | skirt        | black |
# ```

# %%
# Type your code below

# %%
# ANS
product_df = pd.DataFrame({
    'Product ID':[1,2,3,4],
    'Product Name' : ['t-shirt','t-shirt','shirt','shirt'],
    'Color':['blue','green','red','black']
})

# %% [markdown]
# *We dont need to type `print(df)`, because the auto-print function in jupyter is much nicer for dataframe*
#
# Auto-print: Jupyter notebook print the return value of your last statement using the function `IPython.display.display()` internally.

# %% [markdown]
# ```python
# # This is not auto printed
# df = pd.DataFrame({
#     "Product ID": [1,2,3,4],
#     "Product Name": ["t-shirt", "t-shirt", "skirt", "skirt"],
#     "Color": ["blue", "green", "red", "black"],
# })
#
# # This is auto printed
# pd.DataFrame({
#     "Product ID": [1,2,3,4],
#     "Product Name": ["t-shirt", "t-shirt", "skirt", "skirt"],
#     "Color": ["blue", "green", "red", "black"],
# })
# ```
#
# The first statement is not auto-printed because it is a assignment operation (assigning a value to a variable)
#
# The second statement is auto-printed because `pd.DataFrame()` returns a DataFrame object

# %% [markdown]
# ### 3.2 Row data

# %% [markdown]
# - For row data, we pass in a list of lists, where each one represents a row of data.
# - Use the keyword argument `columns` to specify column names.

# %%
 # Example of creating DataFrame with lists

df2 = pd.DataFrame([
        ['John Smith', '123 Main St.', 34],
        ['Jane Doe', '456 Maple Ave.', 28],
        ['Joe Schmo', '789 Broadway', 51]
    ],
    columns=['name', 'address', 'age']
)

df2

# %% [markdown]
# or you can use dictionary for each record

# %%
# Example of creating DataFrame with list of records

df3 = pd.DataFrame([
        {"name": 'John Smith', "address": '123 Main St.', 'age': 34},
        {"name": 'Jane Doe', "address": '456 Maple Ave.', 'age': 28},
        {"name": 'Joe Schmo', "address": '789 Broadway', 'age': 51},
    ]
)

df3

# %% [markdown]
# **Exercise**
#
# > Create a DataFrame with any of the new methods:
# ```
# | Store ID | Location      | Number of Employees |
# |----------|---------------|---------------------|
# | 1        | San Diego     | 100                 |
# | 2        | Los Angeles   | 120                 |
# | 3        | San Francisco | 90                  |
# | 4        | Sacramento    | 115                 |
# ```

# %%
# Type your code below
store_info = [
    [1,'San Diego',100],
    [2, 'Los Angeles',120],
    [3,'San Diego',90],
    [4,'Sacramento',115]
]

# %%
# ANS
store_info = [
    [1,'San Diego',100],
    [2, 'Los Angeles',120],
    [3,'San Diego',90],
    [4,'Sacramento',115]
]

store_df = pd.DataFrame(store_info, columns=['Store ID', 'Location', 'Number of Employees'])

store_df

# %% [markdown]
# ### 3.3 Comma Separated Values (CSV)

# %% [markdown]
# - Most of the time, we’ll be working with datasets that already exist.
#
# - One of the most common formats for big datasets is the CSV.
#
# - CSV (comma separated values) is a text-only spreadsheet format. The first row of a CSV contains column headings. All subsequent rows contain values. Each column heading and each variable is separated by a comma:
#
# ```
# key1,key2,key3
# value1,value2,value3
# value4,value5,value6
# ```

# %% [markdown]
# ### 3.4 Loading and Saving CSVs

# %% [markdown]
# When you have data in a CSV, you can load it into a DataFrame in Pandas using `.read_csv()`:
# ```python
# df = pd.read_csv("my-csv-file.csv")
# ```
# In the example above, the `.read_csv()` method is called. The CSV file called my-csv-file is passed in as an argument.
#
# We can also save data to a CSV, using `.to_csv()`:
# ```python
# df.to_csv('new-csv-file.csv')
# ```
# In the example above, the `.to_csv()` method is called on df (which represents a DataFrame object). The name of the CSV file is passed in as an argument (new-csv-file.csv). By default, this method will save the CSV file in your current directory.

# %%
# demonstration to student
store_df.to_csv('abc.csv')

# %%
pd.read_csv('abc.csv',index_col=0)

# %% [markdown]
# **Exercise**
#
# > 1. Write one of the df you created into `temp.csv`
# 2. Read the CSV `temp.csv` into a variable called `df_reloaded`
# 3. Type `df_reloaded` on the next line and then run your code

# %%
# Type your code here

# %%
# ANS
df1.to_csv('temp.csv', index=False)
df_reloaded = df1.read_csv("temp.csv")
df_reloaded

# %% [markdown]
# ## 4. Inspect a DataFrame

# %% [markdown]
# When we load a new DataFrame from a CSV, we want to know what it looks like.
#
# If it’s a small DataFrame, you can display it by just typing `df`.
#
# If it’s a larger DataFrame, it’s helpful to be able to inspect a few items without having to look at the entire DataFrame.
#
# The method `.head()` gives the first 5 rows of a DataFrame. If you want to see more rows, you can pass in the positional argument n. For example, `df.head(10)` would show the first 10 rows.
#
# The method `df.info()` gives some statistics for each column.
#
# The method `df.describe()` show you technical information.

# %%
store_df.head()

# %%
store_df.info()

# %%
store_df.describe()

# %% [markdown]
# Exercise:
#
# 1. Load the CSV `PP-L1p-Inventory.csv` into a variable called `inventory_df`
# 2. Run `.head(10)` to inspect the first 10 rows of data
# 3. Run `.info()` to inspect the dataset
# 4. Run `.describe()` to inspect the dataset

# %%
# Step 1 has been completed for you
inventory_df = pd.read_csv("https://drive.google.com/u/1/uc?id=1prz6qBT8DanT9RZFDrfb_w2ZAeUEiXS6&export=download")

# Type your code below

# %%
# ANS
inventory_df.head(10)

# %%
inventory_df.info()

# %%
inventory_df.describe()

# %% [markdown]
# ### 4.1 Select Single Column

# %% [markdown]
# Suppose you have the DataFrame called customers, which contains the ages of your customers:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Perhaps you want to take the average of the ages. In order to do the task, you’d need to select the column.
#
# There are two possible syntaxes for selecting all values from a column:
#
# 1. Select the column as if you were selecting a value from a dictionary using a key. In our example, we would type `customers['age']` to select the ages.<br>
#
# 2. If the name of a column follows all of the rules for a variable name (doesn’t start with a number, doesn’t contain spaces or special characters, etc.), then you can select it using the following notation: df.MyColumn. In our example, we would type `customers.age`.<br>
#
# Note: When we select a single column, the result is of `Series` type.

# %% [markdown]
# **Exercise**
#
# > The DataFrame `clinic_df` represents data collected by four health clinics run by the same organization. Each row represents a month from January through June and shows the number of appointments made at four different clinics.
# >
# > You want to analyze what’s been happening at the North location. Create a variable called `clinic_north` that contains ONLY the data from the column `clinic_north`.

# %%
import pandas as pd

clinic_df = pd.DataFrame([
        ['January', 100, 100, 23, 100],
        ['February', 51, 45, 145, 45],
        ['March', 81, 96, 65, 96],
        ['April', 80, 80, 54, 180],
        ['May', 51, 54, 54, 154],
        ['June', 112, 109, 79, 129]
    ],
    columns=['month', 'clinic_east','clinic_north', 'clinic_south','clinic_west']
)

# %%
# Type your code below

# %%
# ANS
clinic_north = clinic_df['clinic_north']
clinic_north

# %% [markdown]
# ### 4.2 Selecting Multiple Columns

# %% [markdown]
# Next step we will select multiple columns.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In this example, we are interested in just the customer’s last_name and email. We want a DataFrame like this:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# To select two or more columns from a DataFrame, we use a list of the column names. To create the DataFrame shown above, we would use:
#
# ```python
# new_df = orders_df[['last_name', 'email']]
# ```
#
# Note: The result is of `DataFrame` type.

# %% [markdown]
# **Exercise**
#
# > Create a variable called `clinic_north_south` that contains ONLY the data from the columns `clinic_north` and `clinic_south`.

# %%
# Type your code below

# %%
# ANS
clinic_north_south = clinic_df[['clinic_north','clinic_south']]
clinic_north_south

# %% [markdown]
# **Checkpoint: What is the difference between the followings?**
#
# ```python
# inventory_df.location
# inventory_df['location']
# inventory_df[['location']]
# ```

# %% [markdown]
# ### 4.3 Select Rows

# %% [markdown]
# Like List, DataFrames are zero-indexed, meaning that we start with the 0th row

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Let's say we want to select the record of Joyce Waller, we select it using the following command:
# ```
# orders.iloc[2]
# ```
# or
# ```
# orders.loc[2]
# ```
#
# - `iloc` lookup a row based on the order of rows
# - `loc` lookup a row based on index (We'll talk about index in next chapter)

# %% [markdown]
# **Exercise**
#
# > Write a command that will produce a Series made up of the March data from `clinic_df` from all four clinic sites and save it to the variable `march`.

# %%
# Type your code below

# %%
# ANS
clinic_df.iloc[2]

# %% [markdown]
# ### 4.4 Selecting Multiple Rows

# %% [markdown]
# You can also select multiple rows from a DataFrame. Here are some different ways of selecting multiple rows (Just like what you do to a List!)

# %% [markdown]
# `df.iloc[3:7]` would select all rows starting at the 3rd row and up to but not including the 7th row (i.e., the 3rd row, 4th row, 5th row, and 6th row)

# %% [markdown]
# `df.iloc[:4]` would select all rows up to, but not including the 4th row (i.e., the 0th, 1st, 2nd, and 3rd rows)

# %% [markdown]
# `df.iloc[-3:]` would select the rows starting at the 3rd to last row and up to and including the final row

# %% [markdown]
# **Exercise**
#
# > Write a command that will produce a DataFrame made up of the data for April, May, and June from `clinic_df` for all four sites (rows 3 through 6), and save it to `april_may_june`

# %%
# Your code here

# %%
# ANS
clinic_df.iloc[3:6]

# %% [markdown]
# **Checkpoint**
# 1. What is the difference between `.iloc` and `.loc`?
# 2. What is the difference between `.iloc[0]` and `.iloc[:1]`?

# %% [markdown]
# ## 5. Anatomy of a DataFrame

# %% [markdown]
# ![anatomy.jpg](data:image/jpeg;base64,...)
#
# Copyright: https://towardsdatascience.com/how-to-master-pandas-for-data-science-b8ab0a9b1042

# %% [markdown]
# **Example**
# Here we verify the data types.
#
# 1. Selecting `.columns` results in an `Index`
# 2. Selecting `.index` results in an `Index`
# 3. Selecting single row results in a `Series`
# 4. Selecting single column results in a `Series`
# 5. Selecting multiple rows results in a `DataFrame`
# 6. Selecting multiple columns results in a `DataFrame`

# %%
df4 = pd.DataFrame([
    {"name": 'John Smith', "address": '123 Main St.', 'age': 34},
    {"name": 'Jane Doe', "address": '456 Maple Ave.', 'age': 28},
    {"name": 'Joe Schmo', "address": '789 Broadway', 'age': 51},
])

# Inspect .columns
print(type(df4.columns))

# Inspect .index
print(type(df4.index))

# Inspect one row
print(type(df4.iloc[0]))

# Inspect some rows
print(type(df4.iloc[:1]))

# Inspect one column
print(type(df4['name']))

# Inspect some columns
print(type(df4[['name']]))

# %% [markdown]
# ## 6. Pairwise operations

# %% [markdown]
# *Pandas* Series provide easy pairwise math caculation.
#
# (To be accurate, pandas only provide the interface.  Actual calculation is done by NumPy which we will visit later)
#
# Try the following:
#
# - pd.Series + pd.Series
# - pd.Series - pd.Series
# - pd.Series * pd.Series
# - pd.Series / pd.Series
# - pd.Series ** pd.Series
# - pd.Series == pd.Series
# - pd.Series > pd.Series

# %% [markdown]
# **Exercise**
#
# > Find the average number of clinic appointments on each month.

# %%
# Type your code below

# %%
# ANS
clinic_avg = (clinic_df['clinic_east'] + clinic_df['clinic_north'] + clinic_df['clinic_south'] + clinic_df['clinic_west'])/4
clinic_avg

# %% [markdown]
# The pairwise operation also works between series and a single value.  Specifically, we use boolean operand to generate some boolean series.

# %%
# Demonstration
clinic_df['clinic_east'] + 1

# %%
# Demonstration
clinic_df['clinic_east'] > 80

# %% [markdown]
# Boolean series is useful when it is used to filter rows.

# %% [markdown]
# ###  6.1 Filter Rows with boolean series

# %% [markdown]
# You can select a subset of a DataFrame by using logical statements:
# ```python
# df[df.MyColumnName == desired_column_value]
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Suppose we want to select all rows where the customer’s age is 30. We would use:
#
# ```python
# df[df.age == 30]
# ```
#
# We can use other logical statements, such as Greater Than, `>`, Less Than, `<` and Not Equal, `!=`

# %% [markdown]
# **Exercise**
#
# > Create variable `january` using a logical statement that selects the row of `clinic_df` where the 'month' column is 'January'.

# %%
# Type your code below

# %%
# ANS
january = clinic_df[clinic_df['month'] == 'January']
january

# %% [markdown]
# ### 6.2 Combination of boolean series

# %% [markdown]
# You can also combine multiple logical statements, as long as each statement is in parentheses.
#
# For instance, suppose we wanted to select all rows where the customer’s age was under 30 or the customer’s name was “Martha Jones”
#
# ```python
# df[(df.age < 30) | (df.name == 'Martha Jones')]
# ```
#
# For pandas series we use,
# - `|` for “or”
# - `&` for “and”
# - `~` for “not”

# %% [markdown]
# **Exercise**
#
# > Create the variable `march_april`, which contains the data from March and April. Do this using two logical statements combined using `|`

# %%
# Type your code below

# %%
# ANS
clinic_df[(clinic_df['month'] == 'March') | (clinic_df['month'] == 'April')]

# %% [markdown]
# ### 6.3 isin

# %% [markdown]
# Suppose we want to select the rows where the customer’s name is either “Martha Jones”, “Rose Tyler” or “Amy Pond”.
#
# We could use the isin command to check that df.name is one of a list of values:
#
# ```python
# import pandas as pd
#
# name_df = pd.DataFrame({
#     "name":['Amy Pond', 'Martha Jones', 'Rose Tyler'],
#     'age':[23,32,25]
# })
#
# name_df.name.isin(["Martha Jones", "Rose Tyler", "Amy Pond"])
# ```

# %% [markdown]
# **Exercise**
#
# > Create the variable `january_february_march`, containing the data from January, February, and March. Do this using a single logical statement with the `isin` command.

# %%
# Type your code below

# %%
# ANS
clinic_df[clinic_df['month'].isin(['January', 'February', 'March'])]
