# %% [markdown]
# ## Statistics in NumPy

# %% [markdown]
# In this lesson, we will learn different methods to calculate common statistical properties of a dataset and understand how we can use statistics to summarize the data.

# %%
# import numpy first
import numpy as np

# %% [markdown]
# ## 1. Mean

# %% [markdown]
# ### 1.1 numpy .mean()

# %% [markdown]
# The mean is an average measurement of a dataset. NumPy has a built-in function to calculate the mean of arrays: `np.mean`
#
# We can then transform the dataset into a NumPy array and use the function `np.mean` to calculate the average

# %%
# Example

survey_responses = [5, 10.2, 4,.3, 6.6]
survey_array = np.array(survey_responses)
np.mean(survey_array)

# %% [markdown]
# **Exercise**
#
# > 1. The sales for the past week for each store are listed. Find the average sales for each store

# %%
store_one = [2, 5, 8, 3, 4, 10, 15, 5]
store_two = [3, 17, 18,  9,  2, 14, 10]
store_three = [7, 5, 4, 3, 2, 7, 7]

# Your code here

# %% [markdown]
# ### 1.2 Logical operations with Mean

# %% [markdown]
# A logical operator will evaluate each item in an array to see if it matches the specified condition. If the item matches the given condition, the item will evaluate as True and equal 1. If it does not match, it will be False and equal 0.
#
# When `np.mean` calculates a logical statement, the resulting mean value will be equivalent to the total number of True items divided by the total array length.

# %%
np.mean(survey_array > 8)

# %% [markdown]
# In thise case, we can use `np.mean` to calculate the percent of array elements that have a certain property

# %% [markdown]
# **Exercise**
# 1. Calculate the percent of attending alumni who graduated on and after 2005 and save your result to the variable `millennials`.

# %%
class_year = np.array([1967, 1949, 2004, 1997, 1953, 1950, 1958, 1974, 1987, 2006, 2013, 1978, 1951, 1998, 1996, 1952, 2005, 2007, 2003, 1955, 1963, 1978, 2001, 2012, 2014, 1948, 1970, 2011, 1962, 1966, 1978, 1988, 2006, 1971, 1994, 1978, 1977, 1960, 2008, 1965, 1990, 2011, 1962, 1995, 2004, 1991, 1952, 2013, 1983, 1955, 1957, 1947, 1994, 1978, 1957, 2016, 1969, 1996, 1958, 1994, 1958, 2008, 1988, 1977, 1991, 1997, 2009, 1976, 1999, 1975, 1949, 1985, 2001, 1952, 1953, 1949, 2015, 2006, 1996, 2015, 2009, 1949, 2004, 2010, 2011, 2001, 1998, 1967, 1994, 1966, 1994, 1986, 1963, 1954, 1963, 1987, 1992, 2008, 1979, 1987])

# Type your code below

# %% [markdown]
# ### 1.3. The Mean of 2D Arrays

# %% [markdown]
# `np.mean` can calculate the means of the larger array as well as the interior values.

# %% [markdown]
# First, we can use `np.mean` to find the mean across all the arrays:

# %%
ring_toss = np.array([[1, 0, 0],
                      [0, 0, 1],
                      [1, 0, 1]])
np.mean(ring_toss)

# %% [markdown]
# To find the means of each interior array, we specify axis = 1 (the “rows”):

# %%
np.mean(ring_toss, axis=1)

# %% [markdown]
# To find the means of each index position, we specify axis 0 (the “columns”):

# %% [markdown]
# **Exercise**
# > 1. We have 5-days trial results for 3 new allergy medication. Use `np.mean` to find the average trial result across all the drugs and save the result to the variable `total_mean`
# 2. Find the average level across days for each drug and save to the variable `trial_mean`
# 3. Find the average level across drugs for each day and  save to the variable `day_mean`

# %%
allergy_trials = np.array([[6, 1, 3, 8, 2],
                           [2, 6, 3, 9, 8],
                           [5, 2, 6, 9, 9]])

# Type your code below

# %% [markdown]
# ## 2. Sorting

# %% [markdown]
# We can use `np.sort` to sort our data

# %%
heights = np.array([49.7, 46.9, 62, 47.2, 47, 48.3, 48.7])
print(heights)
print(np.sort(heights))

# Challenge: How to reverse sort order?

# %% [markdown]
# **Exercise**
# > 1. Sort the temps data array and save the sorted data to `sorted_temps`

# %%
temps = np.array([86, 88, 94, 85, 97, 90, 87, 85, 94, 93, 92, 95, 98, 85, 94, 91, 97, 88, 87, 86, 99, 89, 89, 99, 88, 96, 93, 96, 85, 88, 191, 95, 96, 87, 99, 93, 90, 86, 87, 100, 187, 98, 101, 101, 96, 94, 96, 87, 86, 92, 98,94, 98, 90, 99, 96, 99, 86, 97, 98, 86, 90, 86, 94, 91, 88, 196, 195,93, 97, 199, 87, 87, 90, 90, 98, 88, 92, 97, 88, 85, 94, 88, 93, 198, 90, 91, 90, 92, 92])

# Your code here

# %% [markdown]
# ## 3. Other aggregation functions

# %% [markdown]
# ### 3.1 Median

# %% [markdown]
# NumPy has a function to calculate the median - `np.median()`

# %% [markdown]
# The median is the middle value of a dataset that’s been ordered in terms of magnitude (from lowest to highest).

# %%
a = np.array([1, 1, 2, 3, 4, 5, 5])
np.median(a)

# %% [markdown]
# In this example, the median would be 3

# %% [markdown]
# If the length of our dataset was an even number, the median would be the value halfway between the two central values.

# %%
b = np.array([1, 1, 2, 3, 4, 5, 5, 6])
np.median(b)

# %% [markdown]
# In this example, the median would be 3.5

# %% [markdown]
# In a dataset, the median value can provide an important comparison to the mean. Unlike a mean, the median is not affected by outliers. This becomes important in skewed datasets

# %% [markdown]
# **Exercise**
# 1. Find the median of the temps data array

# %%
temps = np.array([86, 88, 94, 85, 97, 90, 87, 85, 94, 93, 92, 95, 98, 85, 94, 91, 97, 88, 87, 86, 99, 89, 89, 99, 88, 96, 93, 96, 85, 88, 191, 95, 96, 87, 99, 93, 90, 86, 87, 100, 187, 98, 101, 101, 96, 94, 96, 87, 86, 92, 98,94, 98, 90, 99, 96, 99, 86, 97, 98, 86, 90, 86, 94, 91, 88, 196, 195,93, 97, 199, 87, 87, 90, 90, 98, 88, 92, 97, 88, 85, 94, 88, 93, 198, 90, 91, 90, 92, 92])

# Type your code below

# %% [markdown]
# ### 3.2 Percentiles

# %% [markdown]
# As we know, the median is the middle of a dataset: it is the number for which 50% of the samples are below, and 50% of the samples are above. But what if we wanted to find a point at which 40% of the samples are below, and 60% of the samples are above?
#
# This type of point is called a percentile. The Nth percentile is defined as the point N% of samples lie below it. So the point where 40% of samples are below is called the 40th percentilet.

# %% [markdown]
# There are 11 numbers in the dataset. The 40th percentile will have 40% of the 10 remaining numbers below it (40% of 10 is 4) and 60% of the numbers above it (60% of 10 is 6).

# %%
d = [1, 2, 3, 4, 4, 4, 6, 6, 7, 8, 8]

# %% [markdown]
# In NumPy, we can calculate percentiles using the function `np.percentile`, which takes two arguments: the array and the percentile to calculate. So in this example, the 40th percentile is 4.

# %%
np.percentile(d, 40)

# %% [markdown]
# The 25th percentile is called the first quartile and the 75th percentile is called the third quartile. The difference between the first and third quartile is a value called the interquartile range.

# %%
# Example of finding the 25% quantile
np.percentile(d, 25)

# %%
# Example of finding the 75% quantile
np.percentile(d, 75)

# %%
# Example of finding the inter-quartile range
np.percentile(d, 75) - np.percentile(d, 25)

# %% [markdown]
# 50% of the dataset will lie within the interquartile range. The interquartile range gives us an idea of how spread out our data is. The smaller the interquartile range value, the less variance in our dataset.

# %% [markdown]
# **Exercise**
# > 1. Use NumPy to find the 25th and 75th percentiles of Patrons
# 2. Calculate the interquartile range

# %%
patrons = np.array([ 2, 6, 14, 4, 3, 9, 1, 11, 4, 2, 8])

# Type your code below

# %% [markdown]
# ### 3.3 Standard Deviation

# %% [markdown]
# `patrons = np.array([ 2, 6, 14, 4, 3, 9, 1, 11, 4, 2, 8])`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Similar to the interquartile range, the standard deviation tells us the spread of the data. The larger the standard deviation, the more spread out our data is from the center

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We can find the standard deviation of a dataset using the Numpy function `np.std`

# %%
# Example of using standard deviation

nums = np.array([65, 36, 52, 91, 63, 79])
np.std(nums)

# %% [markdown]
# **Exercise**
# > 1. Find the average weight for each dataset
# 2. Calculate the standard deviation for each datasets

# %%
pumpkin = np.array([68, 1820, 1420, 2062, 704, 1156, 1857, 1755, 2092, 1384])

acorn_squash = np.array([20, 43, 99, 200, 12, 250, 58, 120, 230, 215])

# Your code here
