# %% [markdown]
# # Project - Danger's Restaurant

# %% [markdown]
# You have been employed by Danger's Restauratant, the most famous western restaurant in Hong Kong, to digitalise the menu and display it in the screen next to the cashier.
#
#
#
# In this project, you will create variables that store descriptions and prices of various items in a restaurant. You will use what you’ve learned about creating and updating variables to develop itemizations and receipts for your customers.
#
#
#
# Enjoy your journey!

# %% [markdown]
# ### Task #1: Greet the customers

# %% [markdown]
# First we should greet every customer coming to our restaurant: `Good morning, Welcome to Danger Restaurant! Have a good day`
#
#
#
# Steps:
#
# 1. Assign below message to a variable called `greeting`
#
# 2. Use `print()` to show it on the screen

# %%
# Type your code below

# If it is your first time to run code on this workspace, try CTRL + Enter for Window or shift + Enter for Mac

greeting = "Good morning, Welcome to Danger Restaurant! Have a good day"
print(greeting)
# Out:
# Good morning, Welcome to Danger Restaurant! Have a good day

# %% [markdown]
# ### Task #2 Show our customer the menu

# %% [markdown]
# Lets add our breakfast for Monday!
#
#
#
#
#
# Assign the name of breakfast to variables called `breakfast_a_name`, `breakfast_b_name` and `breakfast_c_name`<br>
#
# Assign the description of breakfast to variables called `breakfast_a_description`, `breakfast_b_description` and `breakfast_c_description`
#
#
#
#  A | Name: All Day | Description: Two eggs any style, bacon, toast, hashbrowns or grits, and a short stack of pancakes
#
#  B | Name: Benedict | Description: Two poached eggs, Canadian bacon, sliced avocado, and tomato
#
#  C | Name: Croissant | Description: Bacon, egg and cheese croissant
#
#
#
# Don't forget the drinks!
#
#
#
# Assign the name of drinks to variables called `drink_a_name`, `drink_b_name` and `drink_c_name`<br>
#
# Assign the description of drinks to variables called `drink_a_description`, `drink_b_description` and `drink_c_description`
#
#
#
# A | Name: Latte | Description: Warm and perfectly frothed milk poured with delicate care on top of our specialty espresso
#
# B | Name: Espresso | Description: 100% Arabica, blended and roasted to perfection
#
# C | Name: Capuccino | Description: Thick foam on your creamy bold specialty coffee

# %%
# Type your code below

breakfast_a_name = "All Day"
breakfast_a_description = "Two eggs any style, bacon, toast, hashbrowns or grits, and a short stack of pancakes"

breakfast_b_name = "Benedict"
breakfast_b_description = "Two poached eggs, Canadian bacon, sliced avocado, and tomato"

breakfast_c_name = "Croissant"
breakfast_c_description = "Bacon, egg and cheese croissant"

drink_a_name = "Latte"
drink_a_description = "Warm and perfectly frothed milk poured with delicate care on top of our specialty espresso"

drink_b_name = "Espresso"
drink_b_description = "100% Arabica, blended and roasted to perfection"

drink_c_name = "Capuccino"
drink_c_description = "Thick foam on your creamy bold specialty coffee"

# %% [markdown]
# **Print the menu using string-formatting**

# %%
# Type your code below

print(f'Today breakfast A: {breakfast_a_name} - {breakfast_a_description}')
print(f'Today breakfast B: {breakfast_b_name} - {breakfast_b_description}')
print(f'Today breakfast c: {breakfast_c_name} - {breakfast_c_description}')
print(f'Today drink A: {drink_a_name} - {drink_a_description}')
print(f'Today drink B: {drink_b_name} - {drink_b_description}')
print(f'Today drink C: {drink_c_name} - {drink_c_description}')
# Out:
# Today breakfast A: All Day - Two eggs any style, bacon, toast, hashbrowns or grits, and a short stack of pancakes
# Today breakfast B: Benedict - Two poached eggs, Canadian bacon, sliced avocado, and tomato
# Today breakfast c: Croissant - Bacon, egg and cheese croissant
# Today drink A: Latte - Warm and perfectly frothed milk poured with delicate care on top of our specialty espresso
# Today drink B: Espresso - 100% Arabica, blended and roasted to perfection
# Today drink C: Capuccino - Thick foam on your creamy bold specialty coffee

# %% [markdown]
# ### Task #3 Setup the price

# %% [markdown]
# Lets set the prices for the food and drinks. Assign below price to variables called
#
# - `breakfast_a_price`
#
# - `breakfast_b_price`
#
# - `breakfast_c_price`
#
# - `drink_a_price`
#
# - `drink_b_price`
#
# - `drink_c_price`
#
#
#
#
#
# All Day Breakfast | Price: 90
#
# Benedict | Price: 85
#
# Croissant | Price: 40
#
#
#
# Latte | Price: 35
#
# Espresso | Price: 40
#
# Cappucino | Price: 39

# %%
# Type your code below

breakfast_a_price = 90
breakfast_b_price = 85
breakfast_c_price = 40
drink_a_price = 35
drink_b_price = 40
drink_c_price = 39

# %% [markdown]
# ### Task #4 Obtain the name and the order of the customer

# %% [markdown]
# Our first customer is ready to order! He has chosen All Day Breakfast and Espresso.
#
#
#
# 1. Use the built-in command `input()` to obtain the name the customer and store it into a variable `customer_name`
#
# 2. Create two more variables `breakfast_ordered` and `drink_ordered`.
#
# 3. Create two more variables `price_breakfast_ordered` and `price_drink_ordered`.
#
# 4. Let's just put the information of All Day Breakfast and Espresso into these 4 variables. (Later on, we will make this more dynamic)

# %%
# Type your code below

customer_name = input()
breakfast_ordered = breakfast_a_name
drink_ordered = drink_a_name
price_breakfast_ordered = breakfast_a_price
price_drink_ordered = drink_a_price
# Out:
#  Nathan

# %% [markdown]
# ### Task #5 Calculate the bill for customer

# %% [markdown]
# Now we are ready to calculate the bill for the customer.
#
#
#
# Create a varaible called `total`, add the prices of `price_breakfast_ordered` and `price_drink_ordered`.

# %%
# Type your code below
total = price_breakfast_ordered + price_drink_ordered
print(total)
# Out:
# 125

# %% [markdown]
# ### Task #6 Discount on membership
#
#
#
# Assume this customer is a VIP, who can enjoy 10% off discount.
#
#
#
# Create a varaible called `discounted_total`, to store the discounted price.

# %%
# Type your code below
discounted_total = 0.9*total
print(discounted_total)
# Out:
# 112.5

# %% [markdown]
# ### Task #7 Print the bill
#
#
#
# The bill should look like:
#
# ```
#
# Customer: Klaus
#
# ----------
#
# 1. All Day - $90.00
#
# 2. Espresso - $40.00
#
# ----------
#
# Total: $130.00
#
# Discounted total: $117.00
#
# ```
#
#
#
# Print it out

# %%
# Type your code below
print(f"Customer: {customer_name}")
print("----------")
print(f"1.{breakfast_ordered} - ${price_breakfast_ordered}")
print(f"2.{drink_ordered} - ${price_drink_ordered}")
print("----------")
print(f"Total: ${total}")
print(f"Discounted total: ${discounted_total}")
# Out:
# Customer: Nathan
# ----------
# 1.All Day - $90
# 2.Latte - $35
# ----------
# Total: $125
# Discounted total: $112.5
