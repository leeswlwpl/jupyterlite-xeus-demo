# %% [markdown]
# ## Project - DANGER Shipping

# %% [markdown]
# In DANGER Shipping, there are several options for shipping package:
# 1. Ground shipping, which is a small flat charge plus a rate based on the weight of your package
# 2. Premium ground shipping, which is a much higher flat charge, but you aren’t charged for weight
# 3. Drone shipping, which has no flat charge, but the rate based on weight is triple the rate of ground shipping

# %% [markdown]
# Below is the price list:

# %% [markdown]
# Gound Shipping

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Drone Shipping

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Premium Shipping

# %% [markdown]
# Flat charge: $125.00

# %% [markdown]
# Write a program that asks the user for the weight of their package and then tells them which method of shipping is cheapest and how much it will cost to ship their package

# %% [markdown]
# ### 1. Ground Shipping
# Write a program to calculate the cost of ground shipping with the given `weight` and save it in a variable called `cost_ground_shipping`

# %% [markdown]
# A package that weighs 8.4 pounds should cost $53.60 to ship with normal ground shipping, test your program

# %%
# Write your code below

weight = 8.4
# your code here
print(cost_ground_shipping) #expect 53.6

# %% [markdown]
# ### 2. Premium Shipping
#
# Create a variable for the cost of premium ground shipping

# %%
# Write your code below

# your code here
print(cost_premium_shipping) #expect 125

# %% [markdown]
# ### 3. Drone Shipping
#
# Write a program to calculate the cost of drone shipping with the given `weight` and save it in a variable called `cost_drone_shipping`

# %% [markdown]
# A package that weighs 1.5 pounds should cost $6.75 to ship by drone shipping, test your program

# %%
# Write your code below

weight = 1.5
# your code here
print(cost_drone_shipping) #expect 6.75

# %% [markdown]
# ### 4. Comparison
#
# Write a program that evaluates the three shipping methods and prints a statement that tells the user:
#
# a. Which shipping method that is cheapest <br>
# b. How much it would cost to ship a package of said weight using the cheapest method

# %% [markdown]
# What is the cheapest method of shipping a 4.8 pound package and how much would it cost?
#
# The cheapest way to ship 4.8 pound package is using ground shipping and it will cost $34.40. Test your program

# %%
# Write your code below

weight = 4.8
# your code here
# expect "ground shipping is the cheapest with $34.4"
